# %% [markdown]
# # Programming Assignment 2: Naive Bayes
# ## Part 1: Language Modelling and Text Generation
#
# #### Name: Shehryar Sohail
# #### Roll Number: 24100120
#
# ### Instructions
# *   In this part of the assignment you will be implementing an n-gram model for text-generation.
# *   Your code must be in the Python programming language.
# *   You are encouraged to use procedural programming and throughly comment your code.
# *   For Part 1, in addition to standard libraries i.e. numpy, pandas, regex, matplotlib and scipy, you can use [UrduHack](https://docs.urduhack.com/en/stable/index.html) for tokenization, and [NLKT](https://www.nltk.org/) for training your n-grams. However, no other machine learning toolkits or libraries are allowed.
# *   **Carefully read the submission guidelines, plagiarism and late days policy.**
#
# ### Submission Guidelines
# Submit your code both as notebook file (.ipynb) and python script (.py) as individual files on LMS. Name both files as RollNumber_PA2_PartNum, i.e. this part should be named as `2xxxxxxx_PA4_1`. If you don’t know how to save .ipynb as .py see [this](https://i.stack.imgur.com/L1rQH.png). Failing to submit any one of them might result in the reduction of marks. All cells **MUST** be run to get credit.
#
# ### Plagiarism Policy
# The code **MUST** be done independently. Any plagiarism or cheating of work from others or the internet will be immediately referred to the DC. If you are confused about what constitutes plagiarism, it is **YOUR** responsibility to consult with the instructor or the TA in a timely manner. No “after the fact” negotiations will be possible. The only way to guarantee that you do not lose marks is **DO NOT LOOK AT ANYONE ELSE'S CODE NOR DISCUSS IT WITH THEM**.
#
# ### Late Days Policy
#
# The deadline for the assignment is final. However, in order to accommodate all the 11th-
# hour issues, there is a late submission policy i.e. you can submit your assignment within
# 3 days after the deadline with a 25% deduction each day.

# %% [markdown]
# ### Introduction
# An n-gram is a contiguous sequence of n words. For example "Machine" is a unigram, "Machine Learning" is a bigram and "Machine Learning PA2" is a trigram. In language modeling, n-gram models are probabilistic models of text that use word dependencies and context to predict the likelihood of occurence of an n-gram, i.e. predicting the nth word in an n-gram based on the previous n-1 words:
# $$
# P(ngram) =  P(word|context) = P(x^{n}|x^{n-1},...,x^{1})
# $$
# One use of the predictions made by such a model is text generation. In this part you will be training your own n-gram model and using it to generate text after learning from the provided Urdu short stories.
# <br><br>
# For additional details of the working of n-gram models, you can also consult [Chapter 3](https://web.stanford.edu/~jurafsky/slp3/3.pdf) of the Speech and Language Processing book as and references.
#
#
# ### Dataset
# You will be using the Urdu short stories by Patras Bukhari given in the folder `Urdu Short Stories` in the PA2 zip file for the purposes of this part of the assignment. This contains 6 stories of varying lengths which will serve as inputs for your n-gram model.
# You're required to implement an n-gram model that uses the given stories to generate Urdu text that mimics the input stories.

# %% [markdown]
# Start by importing all required libraries here.

# %%
# import all required libraries here
import numpy as np
import pandas as pd
import matplotlib as plt
import os
import seaborn as sns

# %%
from urduhack.tokenization import sentence_tokenizer
from urduhack.tokenization import word_tokenizer

# %% [markdown]
# ### 1.1 - Loading and Preprocessing the Dataset

# %% [markdown]
# Read in the short story files given and tokenize the text to be preprocessed.

# %%
# code here

file = open('DataP1/cinema ka ishq.txt', encoding="utf8")
urdu1 = file.read()
file = open('DataP1/dost k naam.txt', encoding="utf8")
urdu2 = file.read()
file = open('DataP1/hostel mein parhna.txt', encoding="utf8")
urdu3 = file.read()
file = open('DataP1/lahore ka jughrafiya.txt', encoding="utf8")
urdu4 = file.read()
file = open('DataP1/maibal aur main.txt', encoding="utf8")
urdu5 = file.read()
file = open('DataP1/sawere.txt', encoding="utf8")
urdu6 = file.read()

# %%
urdu1_token = []
urdu2_token = []
urdu3_token = []
urdu4_token = []
urdu5_token = []
urdu6_token = []

sent1 = sentence_tokenizer(urdu1)
sent2 = sentence_tokenizer(urdu2)
sent3 = sentence_tokenizer(urdu3)
sent4 = sentence_tokenizer(urdu4)
sent5 = sentence_tokenizer(urdu5)
sent6 = sentence_tokenizer(urdu6)

# %%
for i in sent1:
    word = word_tokenizer(i)
    for j in word:
        urdu1_token.append(j)

for i in sent2:
    word = word_tokenizer(i)
    for j in word:
        urdu2_token.append(j)

for i in sent3:
    word = word_tokenizer(i)
    for j in word:
        urdu3_token.append(j)

for i in sent4:
    word = word_tokenizer(i)
    for j in word:
        urdu4_token.append(j)

for i in sent5:
    word = word_tokenizer(i)
    for j in word:
        urdu5_token.append(j)

for i in sent6:
    word = word_tokenizer(i)
    for j in word:
        urdu6_token.append(j)
# Out:
# 3/3 [==============================] - 8s 819ms/step
# 2/2 [==============================] - 1s 661ms/step
# 4/4 [==============================] - 3s 597ms/step
# 1/1 [==============================] - 1s 532ms/step
# 6/6 [==============================] - 4s 685ms/step
# 1/1 [==============================] - 1s 666ms/step
# 3/3 [==============================] - 2s 690ms/step
# 2/2 [==============================] - 1s 602ms/step
# 2/2 [==============================] - 1s 81ms/step
# 4/4 [==============================] - 3s 725ms/step
# 2/2 [==============================] - 1s 212ms/step
# 4/4 [==============================] - 3s 600ms/step
# 7/7 [==============================] - 5s 756ms/step
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 500ms/step
# 1/1 [==============================] - 1s 804ms/step
# 4/4 [==============================] - 3s 643ms/step
# 2/2 [==============================] - 1s 445ms/step
# 3/3 [==============================] - 2s 690ms/step
# 1/1 [==============================] - 0s 251ms/step
# 2/2 [==============================] - 1s 241ms/step
# 2/2 [==============================] - 1s 552ms/step
# 1/1 [==============================] - 1s 824ms/step
# 3/3 [==============================] - 2s 759ms/step
# 2/2 [==============================] - 1s 508ms/step
# 1/1 [==============================] - 1s 750ms/step
# 1/1 [==============================] - 0s 498ms/step
# 1/1 [==============================] - 1s 638ms/step
# 2/2 [==============================] - 1s 224ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 570ms/step
# 2/2 [==============================] - 2s 612ms/step
# 2/2 [==============================] - 1s 175ms/step
# 4/4 [==============================] - 3s 798ms/step
# 2/2 [==============================] - 1s 270ms/step
# 2/2 [==============================] - 1s 170ms/step
# 1/1 [==============================] - 1s 742ms/step
# 4/4 [==============================] - 3s 600ms/step
# 2/2 [==============================] - 1s 228ms/step
# 5/5 [==============================] - 3s 647ms/step
# 3/3 [==============================] - 2s 674ms/step
# 2/2 [==============================] - 1s 457ms/step
# 3/3 [==============================] - 2s 568ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 0s 398ms/step
# 4/4 [==============================] - 3s 734ms/step
# 2/2 [==============================] - 1s 551ms/step
# 4/4 [==============================] - 3s 806ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 783ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 595ms/step
# 5/5 [==============================] - 4s 742ms/step
# 1/1 [==============================] - 0s 391ms/step
# 2/2 [==============================] - 1s 187ms/step
# 1/1 [==============================] - 0s 492ms/step
# 2/2 [==============================] - 1s 490ms/step
# 3/3 [==============================] - 2s 665ms/step
# 2/2 [==============================] - 2s 607ms/step
# 1/1 [==============================] - 1s 649ms/step
# 1/1 [==============================] - 1s 632ms/step
# 1/1 [==============================] - 0s 460ms/step
# 3/3 [==============================] - 2s 458ms/step
# 2/2 [==============================] - 1s 183ms/step
# 4/4 [==============================] - 3s 761ms/step
# 1/1 [==============================] - 0s 473ms/step
# 1/1 [==============================] - 1s 638ms/step
# 2/2 [==============================] - 1s 96ms/step
# 1/1 [==============================] - 1s 698ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 526ms/step
# 2/2 [==============================] - 1s 465ms/step
# 5/5 [==============================] - 4s 696ms/step
# 2/2 [==============================] - 2s 826ms/step
# 4/4 [==============================] - 3s 715ms/step
# 2/2 [==============================] - 1s 521ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 714ms/step
# 2/2 [==============================] - 2s 612ms/step
# 1/1 [==============================] - 1s 591ms/step
# 2/2 [==============================] - 1s 454ms/step
# 1/1 [==============================] - 0s 455ms/step
# 1/1 [==============================] - 1s 529ms/step
# 1/1 [==============================] - 1s 701ms/step
# 1/1 [==============================] - 1s 767ms/step
# 2/2 [==============================] - 1s 221ms/step
# 2/2 [==============================] - 1s 416ms/step
# 3/3 [==============================] - 2s 471ms/step
# 1/1 [==============================] - 1s 649ms/step
# 2/2 [==============================] - 1s 452ms/step
# 1/1 [==============================] - 1s 697ms/step
# 1/1 [==============================] - 1s 525ms/step
# 3/3 [==============================] - 2s 534ms/step
# 2/2 [==============================] - 1s 415ms/step
# 1/1 [==============================] - 1s 722ms/step
# 1/1 [==============================] - 1s 654ms/step
# 1/1 [==============================] - 1s 727ms/step
# 2/2 [==============================] - 1s 423ms/step
# 2/2 [==============================] - 2s 543ms/step
# 3/3 [==============================] - 3s 832ms/step
# 3/3 [==============================] - 2s 508ms/step
# 2/2 [==============================] - 1s 275ms/step
# 1/1 [==============================] - 0s 489ms/step
# 1/1 [==============================] - 1s 520ms/step
# 2/2 [==============================] - 1s 124ms/step
# 2/2 [==============================] - 1s 312ms/step
# 3/3 [==============================] - 2s 455ms/step
# 3/3 [==============================] - 2s 768ms/step
# 3/3 [==============================] - 2s 729ms/step
# 4/4 [==============================] - 3s 769ms/step
# 1/1 [==============================] - 1s 845ms/step
# 3/3 [==============================] - 2s 564ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 737ms/step
# 4/4 [==============================] - 3s 607ms/step
# 7/7 [==============================] - 5s 712ms/step
# 1/1 [==============================] - 1s 747ms/step
# 4/4 [==============================] - 3s 710ms/step
# 5/5 [==============================] - 4s 817ms/step
# 3/3 [==============================] - 2s 475ms/step
# 3/3 [==============================] - 2s 532ms/step
# 2/2 [==============================] - 2s 736ms/step
# 2/2 [==============================] - 1s 273ms/step
# 2/2 [==============================] - 2s 663ms/step
# 2/2 [==============================] - 1s 306ms/step
# 2/2 [==============================] - 1s 234ms/step
# 2/2 [==============================] - 2s 625ms/step
# 2/2 [==============================] - 2s 691ms/step
# 4/4 [==============================] - 3s 765ms/step
# 3/3 [==============================] - 2s 502ms/step
# 2/2 [==============================] - 1s 327ms/step
# 4/4 [==============================] - 3s 721ms/step
# 2/2 [==============================] - 1s 290ms/step
# 4/4 [==============================] - 3s 616ms/step
# 1/1 [==============================] - 1s 882ms/step
# 2/2 [==============================] - 1s 418ms/step
# 6/6 [==============================] - 5s 723ms/step
# 1/1 [==============================] - 1s 804ms/step
# 6/6 [==============================] - 5s 730ms/step
# 6/6 [==============================] - 5s 773ms/step
# 4/4 [==============================] - 3s 784ms/step
# 1/1 [==============================] - 0s 478ms/step
# 3/3 [==============================] - 2s 715ms/step
# 6/6 [==============================] - 4s 692ms/step
# 6/6 [==============================] - 5s 847ms/step
# 2/2 [==============================] - 2s 820ms/step
# 4/4 [==============================] - 3s 632ms/step
# 4/4 [==============================] - 3s 640ms/step
# 5/5 [==============================] - 4s 733ms/step
# 2/2 [==============================] - 2s 834ms/step
# 1/1 [==============================] - 1s 692ms/step
# 3/3 [==============================] - 2s 759ms/step
# 3/3 [==============================] - 2s 666ms/step
# 5/5 [==============================] - 4s 845ms/step
# 6/6 [==============================] - 4s 698ms/step
# 2/2 [==============================] - 2s 658ms/step
# 6/6 [==============================] - 5s 827ms/step
# 4/4 [==============================] - 3s 807ms/step
# 1/1 [==============================] - 1s 699ms/step
# 2/2 [==============================] - 1s 180ms/step
# 4/4 [==============================] - 3s 763ms/step
# 2/2 [==============================] - 1s 364ms/step
# 2/2 [==============================] - 1s 476ms/step
# 3/3 [==============================] - 2s 787ms/step
# 5/5 [==============================] - 5s 936ms/step
# 8/8 [==============================] - 6s 765ms/step
# 4/4 [==============================] - 3s 657ms/step
# 7/7 [==============================] - 5s 741ms/step
# 6/6 [==============================] - 5s 761ms/step
# 3/3 [==============================] - 3s 797ms/step
# 4/4 [==============================] - 3s 710ms/step
# 5/5 [==============================] - 4s 835ms/step
# 5/5 [==============================] - 4s 711ms/step
# 5/5 [==============================] - 4s 844ms/step
# 3/3 [==============================] - 2s 742ms/step
# 11/11 [==============================] - 9s 784ms/step
# 3/3 [==============================] - 2s 667ms/step
# 7/7 [==============================] - 5s 753ms/step
# 7/7 [==============================] - 6s 849ms/step
# 15/15 [==============================] - 13s 846ms/step
# 1/1 [==============================] - 1s 708ms/step
# 6/6 [==============================] - 4s 704ms/step
# 2/2 [==============================] - 1s 76ms/step
# 1/1 [==============================] - 1s 894ms/step
# 1/1 [==============================] - 1s 641ms/step
# 1/1 [==============================] - 0s 357ms/step
# 2/2 [==============================] - 1s 228ms/step
# 2/2 [==============================] - 2s 849ms/step
# 1/1 [==============================] - 1s 702ms/step
# 2/2 [==============================] - 2s 877ms/step
# 3/3 [==============================] - 2s 513ms/step
# 5/5 [==============================] - 4s 753ms/step
# 3/3 [==============================] - 2s 732ms/step
# 9/9 [==============================] - 7s 780ms/step
# 2/2 [==============================] - 2s 590ms/step
# 2/2 [==============================] - 2s 849ms/step
# 3/3 [==============================] - 3s 829ms/step
# 3/3 [==============================] - 3s 774ms/step
# 2/2 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 959ms/step
# 4/4 [==============================] - 3s 649ms/step
# 5/5 [==============================] - 4s 679ms/step
# 4/4 [==============================] - 3s 614ms/step
# 1/1 [==============================] - 1s 781ms/step
# 1/1 [==============================] - 1s 840ms/step
# 4/4 [==============================] - 3s 739ms/step
# 3/3 [==============================] - 2s 490ms/step
# 2/2 [==============================] - 2s 766ms/step
# 3/3 [==============================] - 3s 845ms/step
# 3/3 [==============================] - 2s 588ms/step
# 5/5 [==============================] - 4s 699ms/step
# 9/9 [==============================] - 7s 794ms/step
# 2/2 [==============================] - 1s 405ms/step
# 1/1 [==============================] - 1s 809ms/step
# 1/1 [==============================] - 1s 561ms/step
# 2/2 [==============================] - 1s 325ms/step
# 3/3 [==============================] - 3s 867ms/step
# 3/3 [==============================] - 2s 496ms/step
# 2/2 [==============================] - 1s 86ms/step
# 5/5 [==============================] - 4s 837ms/step
# 2/2 [==============================] - 1s 441ms/step
# 2/2 [==============================] - 1s 196ms/step
# 4/4 [==============================] - 3s 646ms/step
# 8/8 [==============================] - 7s 858ms/step
# 2/2 [==============================] - 1s 152ms/step
# 2/2 [==============================] - 1s 462ms/step
# 1/1 [==============================] - 1s 785ms/step
# 1/1 [==============================] - 1s 777ms/step
# 3/3 [==============================] - 3s 983ms/step
# 3/3 [==============================] - 2s 644ms/step
# 3/3 [==============================] - 2s 504ms/step
# 1/1 [==============================] - 1s 838ms/step
# 2/2 [==============================] - 2s 708ms/step
# 2/2 [==============================] - 1s 140ms/step
# 2/2 [==============================] - 1s 208ms/step
# 4/4 [==============================] - 3s 775ms/step
# 3/3 [==============================] - 2s 522ms/step
# 1/1 [==============================] - 1s 521ms/step
# 5/5 [==============================] - 4s 713ms/step
# 2/2 [==============================] - 1s 112ms/step
# 1/1 [==============================] - 1s 647ms/step
# 2/2 [==============================] - 2s 607ms/step
# 7/7 [==============================] - 6s 795ms/step
# 2/2 [==============================] - 1s 136ms/step
# 16/16 [==============================] - 14s 860ms/step
# 4/4 [==============================] - 3s 670ms/step
# 4/4 [==============================] - 3s 823ms/step
# 5/5 [==============================] - 4s 836ms/step
# 3/3 [==============================] - 2s 500ms/step
# 5/5 [==============================] - 4s 749ms/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 2s 704ms/step
# 3/3 [==============================] - 3s 811ms/step
# 3/3 [==============================] - 3s 785ms/step
# 1/1 [==============================] - 1s 518ms/step
# 5/5 [==============================] - 4s 733ms/step
# 3/3 [==============================] - 2s 538ms/step
# 2/2 [==============================] - 1s 344ms/step
# 7/7 [==============================] - 6s 772ms/step
# 3/3 [==============================] - 2s 595ms/step
# 1/1 [==============================] - 1s 712ms/step
# 2/2 [==============================] - 1s 107ms/step
# 1/1 [==============================] - 1s 714ms/step
# 4/4 [==============================] - 3s 750ms/step
# 8/8 [==============================] - 7s 827ms/step
# 2/2 [==============================] - 1s 396ms/step
# 2/2 [==============================] - 1s 433ms/step
# 3/3 [==============================] - 2s 621ms/step
# 2/2 [==============================] - 1s 473ms/step
# 2/2 [==============================] - 1s 297ms/step
# 6/6 [==============================] - 5s 775ms/step
# 3/3 [==============================] - 2s 578ms/step
# 3/3 [==============================] - 3s 1s/step
# 1/1 [==============================] - 1s 936ms/step
# 6/6 [==============================] - 5s 812ms/step
# 4/4 [==============================] - 3s 655ms/step
# 3/3 [==============================] - 2s 595ms/step
# 3/3 [==============================] - 2s 676ms/step
# 10/10 [==============================] - 9s 890ms/step
# 7/7 [==============================] - 6s 841ms/step
# 2/2 [==============================] - 1s 158ms/step
# 4/4 [==============================] - 4s 835ms/step
# 3/3 [==============================] - 3s 937ms/step
# 2/2 [==============================] - 1s 366ms/step
# 2/2 [==============================] - 2s 556ms/step
# 3/3 [==============================] - 3s 896ms/step
# 11/11 [==============================] - 9s 832ms/step
# 4/4 [==============================] - 3s 759ms/step
# 2/2 [==============================] - 2s 771ms/step
# 2/2 [==============================] - 2s 807ms/step
# 5/5 [==============================] - 4s 796ms/step
# 5/5 [==============================] - 5s 1s/step
# 2/2 [==============================] - 1s 557ms/step
# 2/2 [==============================] - 1s 176ms/step
# 2/2 [==============================] - 2s 631ms/step
# 7/7 [==============================] - 6s 814ms/step
# 2/2 [==============================] - 2s 700ms/step
# 5/5 [==============================] - 4s 818ms/step
# 3/3 [==============================] - 2s 574ms/step
# 10/10 [==============================] - 9s 841ms/step
# 1/1 [==============================] - 0s 395ms/step
# 2/2 [==============================] - 2s 852ms/step
# 12/12 [==============================] - 11s 883ms/step
# 4/4 [==============================] - 3s 709ms/step
# 2/2 [==============================] - 1s 162ms/step
# 1/1 [==============================] - 1s 772ms/step
# 1/1 [==============================] - 1s 840ms/step
# 6/6 [==============================] - 5s 728ms/step
# 1/1 [==============================] - 1s 652ms/step
# 4/4 [==============================] - 3s 806ms/step
# 4/4 [==============================] - 4s 834ms/step
# 5/5 [==============================] - 4s 820ms/step
# 3/3 [==============================] - 3s 760ms/step
# 8/8 [==============================] - 7s 868ms/step
# 3/3 [==============================] - 2s 653ms/step
# 3/3 [==============================] - 3s 793ms/step
# 2/2 [==============================] - 2s 619ms/step
# 3/3 [==============================] - 2s 487ms/step
# 5/5 [==============================] - 4s 704ms/step
# 2/2 [==============================] - 2s 727ms/step
# 3/3 [==============================] - 3s 887ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 1s 155ms/step
# 1/1 [==============================] - 1s 939ms/step
# 2/2 [==============================] - 1s 134ms/step
# 6/6 [==============================] - 5s 878ms/step
# 10/10 [==============================] - 9s 900ms/step
# 8/8 [==============================] - 7s 859ms/step
# 1/1 [==============================] - 1s 934ms/step
# 2/2 [==============================] - 2s 1s/step
# 8/8 [==============================] - 7s 814ms/step
# 4/4 [==============================] - 3s 761ms/step
# 4/4 [==============================] - 3s 615ms/step
# 4/4 [==============================] - 4s 899ms/step
# 3/3 [==============================] - 2s 603ms/step
# 4/4 [==============================] - 3s 782ms/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 718ms/step
# 1/1 [==============================] - 0s 448ms/step
# 3/3 [==============================] - 2s 528ms/step
# 3/3 [==============================] - 2s 678ms/step
# 3/3 [==============================] - 2s 623ms/step
# 2/2 [==============================] - 1s 89ms/step
# 4/4 [==============================] - 3s 714ms/step
# 3/3 [==============================] - 3s 874ms/step
# 3/3 [==============================] - 2s 493ms/step
# 2/2 [==============================] - 1s 217ms/step
# 4/4 [==============================] - 3s 736ms/step
# 3/3 [==============================] - 3s 809ms/step
# 3/3 [==============================] - 2s 535ms/step
# 2/2 [==============================] - 2s 778ms/step
# 2/2 [==============================] - 2s 853ms/step
# 2/2 [==============================] - 1s 304ms/step
# 4/4 [==============================] - 3s 730ms/step
# 2/2 [==============================] - 1s 188ms/step
# 7/7 [==============================] - 6s 774ms/step
# 5/5 [==============================] - 4s 823ms/step
# 2/2 [==============================] - 2s 587ms/step
# 6/6 [==============================] - 5s 785ms/step
# 6/6 [==============================] - 5s 875ms/step
# 8/8 [==============================] - 7s 840ms/step
# 3/3 [==============================] - 2s 518ms/step
# 2/2 [==============================] - 1s 448ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 757ms/step
# 1/1 [==============================] - 1s 521ms/step
# 2/2 [==============================] - 1s 549ms/step
# 3/3 [==============================] - 2s 754ms/step
# 1/1 [==============================] - 1s 757ms/step
# 1/1 [==============================] - 1s 846ms/step
# 1/1 [==============================] - 0s 431ms/step
# 4/4 [==============================] - 3s 761ms/step
# 2/2 [==============================] - 2s 832ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 922ms/step
# 2/2 [==============================] - 1s 467ms/step
# 4/4 [==============================] - 4s 869ms/step
# 2/2 [==============================] - 1s 80ms/step
# 2/2 [==============================] - 1s 349ms/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 852ms/step
# 3/3 [==============================] - 2s 561ms/step
# 2/2 [==============================] - 2s 952ms/step
# 2/2 [==============================] - 1s 314ms/step
# 3/3 [==============================] - 2s 599ms/step
# 2/2 [==============================] - 1s 304ms/step
# 2/2 [==============================] - 2s 716ms/step
# 2/2 [==============================] - 1s 435ms/step
# 3/3 [==============================] - 2s 638ms/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 1s 640ms/step
# 1/1 [==============================] - 1s 641ms/step
# 1/1 [==============================] - 1s 774ms/step
# 1/1 [==============================] - 1s 750ms/step
# 4/4 [==============================] - 3s 645ms/step
# 2/2 [==============================] - 1s 245ms/step
# 3/3 [==============================] - 2s 716ms/step
# 1/1 [==============================] - 0s 495ms/step
# 2/2 [==============================] - 1s 265ms/step
# 1/1 [==============================] - 1s 849ms/step
# 4/4 [==============================] - 3s 826ms/step
# 2/2 [==============================] - 2s 921ms/step
# 7/7 [==============================] - 6s 810ms/step
# 4/4 [==============================] - 3s 771ms/step
# 2/2 [==============================] - 2s 671ms/step
# 5/5 [==============================] - 5s 858ms/step
# 3/3 [==============================] - 2s 746ms/step
# 1/1 [==============================] - 1s 673ms/step
# 3/3 [==============================] - 2s 555ms/step
# 2/2 [==============================] - 2s 675ms/step
# 6/6 [==============================] - 5s 744ms/step
# 3/3 [==============================] - 2s 647ms/step
# 1/1 [==============================] - 0s 441ms/step
# 3/3 [==============================] - 3s 786ms/step
# 3/3 [==============================] - 2s 557ms/step
# 2/2 [==============================] - 1s 287ms/step
# 3/3 [==============================] - 3s 948ms/step
# 5/5 [==============================] - 5s 909ms/step
# 8/8 [==============================] - 7s 810ms/step
# 2/2 [==============================] - 2s 1s/step
# 3/3 [==============================] - 3s 791ms/step
# 2/2 [==============================] - 1s 168ms/step
# 1/1 [==============================] - 1s 632ms/step
# 5/5 [==============================] - 4s 746ms/step
# 2/2 [==============================] - 1s 502ms/step
# 4/4 [==============================] - 3s 794ms/step
# 3/3 [==============================] - 2s 718ms/step
# 2/2 [==============================] - 2s 874ms/step
# 2/2 [==============================] - 2s 682ms/step
# 6/6 [==============================] - 6s 908ms/step
# 2/2 [==============================] - 1s 550ms/step
# 2/2 [==============================] - 1s 371ms/step
# 4/4 [==============================] - 3s 755ms/step
# 2/2 [==============================] - 2s 885ms/step
# 3/3 [==============================] - 3s 886ms/step
# 11/11 [==============================] - 10s 873ms/step
# 3/3 [==============================] - 2s 720ms/step
# 2/2 [==============================] - 2s 693ms/step
# 2/2 [==============================] - 1s 417ms/step
# 4/4 [==============================] - 4s 804ms/step
# 2/2 [==============================] - 1s 298ms/step
# 7/7 [==============================] - 6s 914ms/step
# 3/3 [==============================] - 2s 552ms/step
# 5/5 [==============================] - 4s 869ms/step
# 2/2 [==============================] - 2s 848ms/step
# 2/2 [==============================] - 2s 984ms/step
# 4/4 [==============================] - 3s 620ms/step
# 4/4 [==============================] - 3s 678ms/step
# 3/3 [==============================] - 3s 903ms/step
# 1/1 [==============================] - 1s 854ms/step
# 7/7 [==============================] - 6s 840ms/step
# 2/2 [==============================] - 1s 298ms/step
# 3/3 [==============================] - 3s 797ms/step
# 7/7 [==============================] - 6s 816ms/step
# 1/1 [==============================] - 1s 714ms/step
# 4/4 [==============================] - 3s 682ms/step
# 8/8 [==============================] - 7s 798ms/step
# 3/3 [==============================] - 2s 498ms/step
# 3/3 [==============================] - 2s 581ms/step
# 2/2 [==============================] - 1s 199ms/step
# 3/3 [==============================] - 2s 705ms/step
# 1/1 [==============================] - 1s 966ms/step
# 3/3 [==============================] - 2s 497ms/step
# 3/3 [==============================] - 3s 746ms/step
# 2/2 [==============================] - 1s 141ms/step
# 3/3 [==============================] - 3s 826ms/step
# 3/3 [==============================] - 2s 704ms/step
# 2/2 [==============================] - 1s 170ms/step
# 3/3 [==============================] - 3s 857ms/step
# 3/3 [==============================] - 3s 790ms/step
# 1/1 [==============================] - 1s 902ms/step
# 2/2 [==============================] - 1s 353ms/step
# 2/2 [==============================] - 2s 802ms/step
# 4/4 [==============================] - 3s 721ms/step
# 5/5 [==============================] - 5s 954ms/step
# 2/2 [==============================] - 2s 495ms/step
# 5/5 [==============================] - 4s 720ms/step
# 3/3 [==============================] - 2s 490ms/step
# 3/3 [==============================] - 3s 770ms/step
# 2/2 [==============================] - 1s 299ms/step
# 2/2 [==============================] - 2s 634ms/step
# 2/2 [==============================] - 2s 729ms/step
# 2/2 [==============================] - 2s 392ms/step
# 3/3 [==============================] - 2s 556ms/step
# 4/4 [==============================] - 3s 616ms/step
# 2/2 [==============================] - 1s 545ms/step
# 3/3 [==============================] - 2s 585ms/step
# 2/2 [==============================] - 1s 449ms/step
# 5/5 [==============================] - 5s 895ms/step
# 3/3 [==============================] - 2s 539ms/step
# 3/3 [==============================] - 2s 523ms/step
# 4/4 [==============================] - 3s 771ms/step
# 4/4 [==============================] - 3s 670ms/step
# 7/7 [==============================] - 6s 810ms/step
# 4/4 [==============================] - 4s 876ms/step
# 2/2 [==============================] - 2s 627ms/step
# 2/2 [==============================] - 2s 826ms/step
# 2/2 [==============================] - 2s 682ms/step
# 2/2 [==============================] - 2s 530ms/step
# 3/3 [==============================] - 2s 632ms/step
# 3/3 [==============================] - 3s 768ms/step
# 4/4 [==============================] - 3s 789ms/step
# 1/1 [==============================] - 1s 977ms/step
# 2/2 [==============================] - 2s 864ms/step
# 3/3 [==============================] - 2s 626ms/step
# 2/2 [==============================] - 2s 465ms/step
# 1/1 [==============================] - 1s 554ms/step
# 1/1 [==============================] - 1s 781ms/step
# 3/3 [==============================] - 2s 510ms/step
# 10/10 [==============================] - 9s 908ms/step
# 5/5 [==============================] - 4s 775ms/step
# 7/7 [==============================] - 6s 769ms/step
# 1/1 [==============================] - 1s 532ms/step
# 3/3 [==============================] - 3s 758ms/step
# 5/5 [==============================] - 4s 739ms/step
# 3/3 [==============================] - 3s 914ms/step
# 2/2 [==============================] - 2s 897ms/step
# 4/4 [==============================] - 3s 745ms/step
# 3/3 [==============================] - 2s 701ms/step
# 2/2 [==============================] - 2s 642ms/step
# 3/3 [==============================] - 3s 826ms/step
# 3/3 [==============================] - 3s 782ms/step
# 2/2 [==============================] - 2s 717ms/step
# 1/1 [==============================] - 1s 811ms/step
# 1/1 [==============================] - 1s 1s/step
# 4/4 [==============================] - 3s 784ms/step
# 2/2 [==============================] - 1s 219ms/step
# 2/2 [==============================] - 2s 492ms/step
# 2/2 [==============================] - 1s 282ms/step
# 4/4 [==============================] - 3s 770ms/step
# 2/2 [==============================] - 1s 84ms/step
# 1/1 [==============================] - 1s 911ms/step
# 2/2 [==============================] - 1s 190ms/step
# 2/2 [==============================] - 1s 317ms/step
# 2/2 [==============================] - 1s 310ms/step
# 2/2 [==============================] - 2s 783ms/step
# 1/1 [==============================] - 1s 948ms/step
# 2/2 [==============================] - 1s 526ms/step
# 5/5 [==============================] - 5s 720ms/step
# 3/3 [==============================] - 2s 626ms/step
# 3/3 [==============================] - 2s 574ms/step
# 1/1 [==============================] - 1s 913ms/step
# 4/4 [==============================] - 3s 688ms/step
# 2/2 [==============================] - 1s 504ms/step
# 3/3 [==============================] - 3s 935ms/step
# 4/4 [==============================] - 3s 811ms/step
# 8/8 [==============================] - 8s 917ms/step
# 6/6 [==============================] - 6s 893ms/step
# 4/4 [==============================] - 3s 732ms/step
# 3/3 [==============================] - 2s 649ms/step
# 2/2 [==============================] - 1s 217ms/step
# 2/2 [==============================] - 2s 753ms/step
# 2/2 [==============================] - 2s 734ms/step
# 2/2 [==============================] - 1s 250ms/step
# 5/5 [==============================] - 4s 865ms/step
# 1/1 [==============================] - 1s 504ms/step
# 2/2 [==============================] - 1s 231ms/step
# 4/4 [==============================] - 3s 741ms/step
# 2/2 [==============================] - 1s 307ms/step
# 7/7 [==============================] - 6s 853ms/step
# 3/3 [==============================] - 3s 786ms/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 1s 404ms/step
# 3/3 [==============================] - 2s 721ms/step
# 2/2 [==============================] - 2s 748ms/step
# 4/4 [==============================] - 4s 962ms/step
# 2/2 [==============================] - 1s 270ms/step
# 6/6 [==============================] - 6s 903ms/step
# 3/3 [==============================] - 3s 840ms/step
# 1/1 [==============================] - 0s 443ms/step
# 1/1 [==============================] - 1s 910ms/step
# 3/3 [==============================] - 2s 641ms/step
# 2/2 [==============================] - 2s 677ms/step
# 2/2 [==============================] - 2s 613ms/step
# 2/2 [==============================] - 1s 384ms/step
# 4/4 [==============================] - 3s 640ms/step
# 5/5 [==============================] - 4s 838ms/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 1s 385ms/step
# 2/2 [==============================] - 2s 672ms/step
# 2/2 [==============================] - 2s 582ms/step
# 2/2 [==============================] - 1s 427ms/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 2s 829ms/step
# 2/2 [==============================] - 2s 629ms/step
# 2/2 [==============================] - 2s 885ms/step
# 4/4 [==============================] - 3s 700ms/step
# 4/4 [==============================] - 3s 824ms/step
# 2/2 [==============================] - 2s 842ms/step
# 3/3 [==============================] - 2s 666ms/step
# 4/4 [==============================] - 4s 1s/step
# 4/4 [==============================] - 4s 908ms/step
# 5/5 [==============================] - 5s 934ms/step
# 1/1 [==============================] - 1s 887ms/step
# 3/3 [==============================] - 2s 627ms/step
# 2/2 [==============================] - 1s 201ms/step
# 2/2 [==============================] - 1s 345ms/step
# 2/2 [==============================] - 1s 207ms/step
# 2/2 [==============================] - 2s 954ms/step
# 3/3 [==============================] - 2s 614ms/step
# 4/4 [==============================] - 4s 931ms/step
# 5/5 [==============================] - 5s 870ms/step
# 4/4 [==============================] - 3s 802ms/step
# 5/5 [==============================] - 4s 789ms/step
# 8/8 [==============================] - 7s 903ms/step
# 3/3 [==============================] - 3s 765ms/step
# 1/1 [==============================] - 1s 1s/step
# 3/3 [==============================] - 2s 631ms/step
# 2/2 [==============================] - 2s 607ms/step
# 3/3 [==============================] - 3s 934ms/step
# 4/4 [==============================] - 3s 718ms/step
# 4/4 [==============================] - 3s 653ms/step
# 4/4 [==============================] - 3s 644ms/step
# 2/2 [==============================] - 2s 848ms/step
# 2/2 [==============================] - 2s 405ms/step
# 1/1 [==============================] - 1s 871ms/step
# 2/2 [==============================] - 2s 909ms/step
# 2/2 [==============================] - 1s 300ms/step
# 6/6 [==============================] - 5s 876ms/step
# 2/2 [==============================] - 1s 84ms/step
# 2/2 [==============================] - 2s 901ms/step
# 2/2 [==============================] - 1s 143ms/step
# 5/5 [==============================] - 4s 759ms/step
# 3/3 [==============================] - 2s 678ms/step
# 1/1 [==============================] - 1s 739ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 846ms/step
# 6/6 [==============================] - 5s 758ms/step
# 3/3 [==============================] - 3s 899ms/step
# 1/1 [==============================] - 0s 427ms/step
# 1/1 [==============================] - 1s 979ms/step
# 4/4 [==============================] - 4s 988ms/step
# 1/1 [==============================] - 1s 888ms/step
# 2/2 [==============================] - 1s 195ms/step
# 2/2 [==============================] - 2s 691ms/step
# 3/3 [==============================] - 2s 703ms/step
# 3/3 [==============================] - 2s 473ms/step
# 1/1 [==============================] - 1s 1s/step
# 6/6 [==============================] - 5s 800ms/step
# 2/2 [==============================] - 2s 626ms/step
# 3/3 [==============================] - 3s 1s/step
# 2/2 [==============================] - 1s 288ms/step
# 1/1 [==============================] - 1s 927ms/step
# 1/1 [==============================] - 1s 985ms/step
# 2/2 [==============================] - 2s 793ms/step
# 3/3 [==============================] - 3s 853ms/step
# 6/6 [==============================] - 5s 872ms/step
# 5/5 [==============================] - 4s 716ms/step
# 4/4 [==============================] - 4s 834ms/step
# 5/5 [==============================] - 5s 917ms/step
# 2/2 [==============================] - 2s 370ms/step
# 1/1 [==============================] - 1s 540ms/step
# 1/1 [==============================] - 1s 859ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 2s 470ms/step
# 1/1 [==============================] - 1s 976ms/step
# 4/4 [==============================] - 3s 733ms/step
# 1/1 [==============================] - 1s 930ms/step
# 2/2 [==============================] - 2s 455ms/step
# 3/3 [==============================] - 3s 643ms/step
# 2/2 [==============================] - 2s 526ms/step
# 2/2 [==============================] - 1s 114ms/step
# 2/2 [==============================] - 1s 178ms/step
# 5/5 [==============================] - 5s 892ms/step
# 2/2 [==============================] - 2s 724ms/step
# 2/2 [==============================] - 1s 347ms/step
# 5/5 [==============================] - 4s 824ms/step
# 7/7 [==============================] - 7s 1s/step
# 3/3 [==============================] - 3s 824ms/step
# 2/2 [==============================] - 1s 365ms/step
# 5/5 [==============================] - 4s 816ms/step
# 2/2 [==============================] - 2s 1s/step
# 4/4 [==============================] - 3s 804ms/step
# 6/6 [==============================] - 6s 897ms/step
# 2/2 [==============================] - 2s 544ms/step
# 3/3 [==============================] - 3s 724ms/step
# 6/6 [==============================] - 6s 960ms/step
# 4/4 [==============================] - 4s 859ms/step
# 5/5 [==============================] - 5s 967ms/step
# 7/7 [==============================] - 6s 797ms/step
# 2/2 [==============================] - 2s 1s/step
# 4/4 [==============================] - 4s 1s/step
# 2/2 [==============================] - 2s 779ms/step
# 3/3 [==============================] - 2s 599ms/step
# 2/2 [==============================] - 2s 714ms/step
# 1/1 [==============================] - 1s 856ms/step
# 2/2 [==============================] - 2s 525ms/step
# 3/3 [==============================] - 3s 982ms/step
# 4/4 [==============================] - 4s 800ms/step
# 2/2 [==============================] - 2s 450ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 623ms/step
# 3/3 [==============================] - 3s 797ms/step
# 6/6 [==============================] - 5s 794ms/step
# 1/1 [==============================] - 1s 715ms/step
# 3/3 [==============================] - 3s 848ms/step
# 6/6 [==============================] - 6s 1s/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 0s 441ms/step
# 2/2 [==============================] - 1s 422ms/step
# 3/3 [==============================] - 2s 576ms/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 1s 204ms/step
# 1/1 [==============================] - 1s 864ms/step
# 2/2 [==============================] - 2s 385ms/step
# 3/3 [==============================] - 3s 1s/step
# 2/2 [==============================] - 1s 366ms/step
# 2/2 [==============================] - 2s 997ms/step
# 5/5 [==============================] - 5s 980ms/step
# 5/5 [==============================] - 4s 805ms/step
# 5/5 [==============================] - 4s 806ms/step
# 4/4 [==============================] - 3s 755ms/step
# 2/2 [==============================] - 1s 256ms/step
# 3/3 [==============================] - 3s 769ms/step
# 3/3 [==============================] - 3s 1s/step
# 2/2 [==============================] - 2s 821ms/step
# 1/1 [==============================] - 1s 994ms/step
# 2/2 [==============================] - 2s 823ms/step
# 3/3 [==============================] - 3s 939ms/step
# 4/4 [==============================] - 3s 770ms/step
# 2/2 [==============================] - 1s 461ms/step
# 3/3 [==============================] - 3s 1s/step
# 3/3 [==============================] - 3s 998ms/step
# 3/3 [==============================] - 2s 591ms/step
# 3/3 [==============================] - 3s 1s/step
# 3/3 [==============================] - 3s 1s/step
# 2/2 [==============================] - 1s 131ms/step
# 2/2 [==============================] - 1s 436ms/step
# 1/1 [==============================] - 1s 782ms/step
# 3/3 [==============================] - 3s 826ms/step
# 4/4 [==============================] - 4s 896ms/step
# 3/3 [==============================] - 2s 714ms/step
# 2/2 [==============================] - 2s 1s/step
# 6/6 [==============================] - 5s 814ms/step
# 1/1 [==============================] - 1s 819ms/step
# 2/2 [==============================] - 2s 693ms/step
# 2/2 [==============================] - 1s 146ms/step
# 1/1 [==============================] - 1s 724ms/step
# 2/2 [==============================] - 1s 284ms/step
# 3/3 [==============================] - 2s 656ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 701ms/step
# 1/1 [==============================] - 1s 937ms/step
# 2/2 [==============================] - 2s 973ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 922ms/step
# 2/2 [==============================] - 2s 904ms/step
# 3/3 [==============================] - 3s 843ms/step
# 1/1 [==============================] - 1s 683ms/step
# 2/2 [==============================] - 2s 859ms/step
# 3/3 [==============================] - 3s 1s/step
# 2/2 [==============================] - 2s 433ms/step
# 2/2 [==============================] - 2s 350ms/step
# 2/2 [==============================] - 3s 1s/step
# 2/2 [==============================] - 2s 420ms/step
# 6/6 [==============================] - 6s 941ms/step
# 2/2 [==============================] - 2s 825ms/step
# 3/3 [==============================] - 3s 866ms/step
# 2/2 [==============================] - 1s 250ms/step
# 9/9 [==============================] - 8s 897ms/step
# 2/2 [==============================] - 2s 729ms/step
# 3/3 [==============================] - 3s 688ms/step
# 1/1 [==============================] - 1s 796ms/step
# 1/1 [==============================] - 0s 460ms/step
# 1/1 [==============================] - 0s 463ms/step
# 2/2 [==============================] - 2s 581ms/step
# 1/1 [==============================] - 1s 886ms/step
# 2/2 [==============================] - 2s 559ms/step
# 3/3 [==============================] - 3s 778ms/step
# 2/2 [==============================] - 1s 222ms/step
# 2/2 [==============================] - 2s 486ms/step
# 1/1 [==============================] - 1s 835ms/step
# 5/5 [==============================] - 5s 936ms/step
# 2/2 [==============================] - 1s 394ms/step
# 3/3 [==============================] - 2s 628ms/step
# 8/8 [==============================] - 8s 977ms/step
# 3/3 [==============================] - 3s 824ms/step
# 2/2 [==============================] - 2s 706ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 1s 652ms/step
# 2/2 [==============================] - 1s 166ms/step
# 1/1 [==============================] - 1s 911ms/step
# 2/2 [==============================] - 2s 593ms/step
# 3/3 [==============================] - 2s 573ms/step
# 1/1 [==============================] - 0s 457ms/step
# 1/1 [==============================] - 1s 737ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 343ms/step
# 1/1 [==============================] - 0s 463ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 515ms/step
# 4/4 [==============================] - 4s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 1s 284ms/step
# 3/3 [==============================] - 3s 569ms/step
# 2/2 [==============================] - 2s 664ms/step
# 2/2 [==============================] - 2s 374ms/step
# 5/5 [==============================] - 4s 795ms/step
# 1/1 [==============================] - 1s 680ms/step
# 7/7 [==============================] - 6s 801ms/step
# 2/2 [==============================] - 1s 127ms/step
# 1/1 [==============================] - 0s 464ms/step
# 1/1 [==============================] - 1s 925ms/step
# 1/1 [==============================] - 1s 721ms/step
# 1/1 [==============================] - 1s 841ms/step
# 6/6 [==============================] - 5s 787ms/step
# 2/2 [==============================] - 2s 723ms/step
# 1/1 [==============================] - 1s 706ms/step
# 1/1 [==============================] - 0s 333ms/step
# 3/3 [==============================] - 2s 623ms/step
# 1/1 [==============================] - 1s 544ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 1s 750ms/step
# 1/1 [==============================] - 0s 451ms/step
# 2/2 [==============================] - 3s 1s/step
# 1/1 [==============================] - 1s 526ms/step
# 5/5 [==============================] - 5s 924ms/step
# 1/1 [==============================] - 1s 941ms/step
# 5/5 [==============================] - 5s 894ms/step
# 2/2 [==============================] - 2s 854ms/step
# 1/1 [==============================] - 1s 849ms/step
# 3/3 [==============================] - 3s 959ms/step
# 2/2 [==============================] - 1s 246ms/step
# 2/2 [==============================] - 2s 1s/step
# 3/3 [==============================] - 2s 625ms/step
# 1/1 [==============================] - 1s 862ms/step
# 2/2 [==============================] - 1s 468ms/step
# 3/3 [==============================] - 3s 763ms/step
# 4/4 [==============================] - 3s 720ms/step
# 1/1 [==============================] - 1s 1s/step
# 4/4 [==============================] - 3s 750ms/step
# 2/2 [==============================] - 2s 779ms/step
# 1/1 [==============================] - 1s 626ms/step
# 2/2 [==============================] - 2s 1s/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 676ms/step
# 2/2 [==============================] - 2s 841ms/step
# 2/2 [==============================] - 1s 270ms/step
# 2/2 [==============================] - 2s 509ms/step
# 7/7 [==============================] - 6s 895ms/step
# 2/2 [==============================] - 1s 406ms/step
# 1/1 [==============================] - 1s 644ms/step
# 2/2 [==============================] - 1s 139ms/step
# 1/1 [==============================] - 0s 369ms/step
# 1/1 [==============================] - 0s 250ms/step
# 2/2 [==============================] - 1s 485ms/step
# 2/2 [==============================] - 1s 127ms/step
# 1/1 [==============================] - 1s 964ms/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 890ms/step
# 3/3 [==============================] - 3s 822ms/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 2s 1s/step
# 2/2 [==============================] - 2s 859ms/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 2s 727ms/step
# 6/6 [==============================] - 6s 941ms/step
# 3/3 [==============================] - 3s 768ms/step
# 3/3 [==============================] - 2s 693ms/step
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 1s 854ms/step
# 1/1 [==============================] - 1s 872ms/step
# 2/2 [==============================] - 1s 186ms/step
# 2/2 [==============================] - 2s 747ms/step
# 3/3 [==============================] - 3s 995ms/step
# 1/1 [==============================] - 1s 541ms/step
# 1/1 [==============================] - 1s 928ms/step
# 2/2 [==============================] - 2s 783ms/step
# 1/1 [==============================] - 0s 293ms/step
# 3/3 [==============================] - 2s 550ms/step
# 2/2 [==============================] - 1s 434ms/step
# 3/3 [==============================] - 3s 698ms/step
# 4/4 [==============================] - 4s 838ms/step
# 3/3 [==============================] - 3s 945ms/step
# 5/5 [==============================] - 5s 1s/step
# 3/3 [==============================] - 3s 864ms/step
# 2/2 [==============================] - 1s 388ms/step
# 3/3 [==============================] - 2s 647ms/step
# 2/2 [==============================] - 2s 999ms/step
# 2/2 [==============================] - 1s 280ms/step
# 1/1 [==============================] - 0s 473ms/step
# 2/2 [==============================] - 2s 607ms/step
# 10/10 [==============================] - 11s 1s/step
# 6/6 [==============================] - 5s 863ms/step
# 2/2 [==============================] - 1s 93ms/step
# 3/3 [==============================] - 2s 680ms/step
# 2/2 [==============================] - 2s 876ms/step
# 1/1 [==============================] - 1s 975ms/step
# 1/1 [==============================] - 1s 843ms/step
# 2/2 [==============================] - 1s 389ms/step
# 5/5 [==============================] - 5s 887ms/step
# 2/2 [==============================] - 2s 510ms/step
# 5/5 [==============================] - 4s 838ms/step
# 2/2 [==============================] - 2s 396ms/step
# 3/3 [==============================] - 3s 958ms/step
# 2/2 [==============================] - 1s 183ms/step
# 3/3 [==============================] - 3s 913ms/step
# 1/1 [==============================] - 1s 774ms/step
# 2/2 [==============================] - 2s 668ms/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 2s 652ms/step
# 2/2 [==============================] - 2s 1s/step
# 1/1 [==============================] - 1s 983ms/step
# 2/2 [==============================] - 1s 322ms/step
# 1/1 [==============================] - 1s 569ms/step
# 2/2 [==============================] - 2s 376ms/step
# 2/2 [==============================] - 2s 564ms/step
# 2/2 [==============================] - 2s 758ms/step
# 2/2 [==============================] - 2s 962ms/step
# 1/1 [==============================] - 1s 530ms/step
# 3/3 [==============================] - 2s 690ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 523ms/step
# 1/1 [==============================] - 1s 648ms/step
# 2/2 [==============================] - 2s 581ms/step
# 2/2 [==============================] - 1s 309ms/step
# 1/1 [==============================] - 1s 779ms/step
# 1/1 [==============================] - 1s 941ms/step
# 4/4 [==============================] - 4s 1s/step
# 3/3 [==============================] - 2s 642ms/step
# 1/1 [==============================] - 1s 591ms/step
# 4/4 [==============================] - 4s 841ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 975ms/step
# 1/1 [==============================] - 0s 485ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 357ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 1s 696ms/step
# 5/5 [==============================] - 5s 927ms/step
# 2/2 [==============================] - 2s 806ms/step
# 2/2 [==============================] - 2s 891ms/step
# 2/2 [==============================] - 2s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 2/2 [==============================] - 1s 260ms/step
# 1/1 [==============================] - 0s 424ms/step
# 3/3 [==============================] - 3s 679ms/step
# 2/2 [==============================] - 1s 387ms/step
# 4/4 [==============================] - 3s 711ms/step
# 2/2 [==============================] - 1s 132ms/step
# 3/3 [==============================] - 3s 996ms/step
# 1/1 [==============================] - 1s 718ms/step
# 4/4 [==============================] - 3s 771ms/step
# 2/2 [==============================] - 1s 355ms/step
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - 1s 758ms/step
# 7/7 [==============================] - 7s 913ms/step
# 2/2 [==============================] - 2s 686ms/step
# 5/5 [==============================] - 5s 845ms/step
# 8/8 [==============================] - 8s 936ms/step
# 2/2 [==============================] - 1s 344ms/step
# 4/4 [==============================] - 4s 924ms/step
# 12/12 [==============================] - 12s 1000ms/step
# 2/2 [==============================] - 2s 935ms/step
# 1/1 [==============================] - 1s 888ms/step
# 1/1 [==============================] - 1s 713ms/step

# %%
#Checking Tokens
len(urdu1_token) + len(urdu2_token) + len(urdu3_token) + len(urdu4_token) + len(urdu5_token) + len(urdu6_token)
# Out:
# 16017

# %%
# This cell is to save the data that has been learnt bcz learning takes a lot of time and you don't wanna learn 
# again and again and waste time (learning time approx > 1 hr) 
# so here you save the data in the file and comment out the learning bit above.


# #Saving Tokenization progress
# with open(r'Tokens Part1\Story1Tokens.txt', 'w' , encoding="utf8") as fp:
#     for item in urdu1_token:
#         fp.write("%s\n" % item)
#     print('Done')
# with open(r'Tokens Part1\Story2Tokens.txt', 'w' , encoding="utf8") as fp:
#     for item in urdu2_token:
#         fp.write("%s\n" % item)
#     print('Done')
# with open(r'Tokens Part1\Story3Tokens.txt', 'w' , encoding="utf8") as fp:
#     for item in urdu3_token:
#         fp.write("%s\n" % item)
#     print('Done')
# with open(r'Tokens Part1\Story4Tokens.txt', 'w' , encoding="utf8") as fp:
#     for item in urdu4_token:
#         fp.write("%s\n" % item)
#     print('Done')
# with open(r'Tokens Part1\Story5Tokens.txt', 'w' , encoding="utf8") as fp:
#     for item in urdu5_token:
#         fp.write("%s\n" % item)
#     print('Done')
# with open(r'Tokens Part1\Story6Tokens.txt', 'w' , encoding="utf8") as fp:
#     for item in urdu6_token:
#         fp.write("%s\n" % item)
#     print('Done')

# %% [markdown]
# Preprocess the tokenized data. Go through the data and use your own discretion to decide on what kind of pre-processing might be required.

# %%
# Here you read from the file and continue with your work.

# #Read from file
# with open(r'Tokens Part1\Story1Tokens.txt', encoding="utf8") as f:
#     urdu1_token = f.read().splitlines()
# with open(r'Tokens Part1\Story2Tokens.txt', encoding="utf8") as f:
#     urdu2_token = f.read().splitlines()
# with open(r'Tokens Part1\Story3Tokens.txt', encoding="utf8") as f:
#     urdu3_token = f.read().splitlines()
# with open(r'Tokens Part1\Story4Tokens.txt', encoding="utf8") as f:
#     urdu4_token = f.read().splitlines()
# with open(r'Tokens Part1\Story5Tokens.txt', encoding="utf8") as f:
#     urdu5_token = f.read().splitlines()
# with open(r'Tokens Part1\Story6Tokens.txt', encoding="utf8") as f:
#     urdu6_token = f.read().splitlines()

# %%
from urduhack.preprocessing import remove_punctuation

# %%
#remove Punctuation
for i in range(len(urdu1_token)):
    urdu1_token[i] = remove_punctuation(urdu1_token[i])
while("" in urdu1_token):
    urdu1_token.remove("")

for i in range(len(urdu2_token)):
    urdu2_token[i] = remove_punctuation(urdu2_token[i])
while("" in urdu2_token):
    urdu2_token.remove("")
    
for i in range(len(urdu3_token)):
    urdu3_token[i] = remove_punctuation(urdu3_token[i])
while("" in urdu3_token):
    urdu3_token.remove("")
    
for i in range(len(urdu4_token)):
    urdu4_token[i] = remove_punctuation(urdu4_token[i])
while("" in urdu4_token):
    urdu4_token.remove("")
    
for i in range(len(urdu5_token)):
    urdu5_token[i] = remove_punctuation(urdu5_token[i])
while("" in urdu5_token):
    urdu5_token.remove("")
    
for i in range(len(urdu6_token)):
    urdu6_token[i] = remove_punctuation(urdu6_token[i])
while("" in urdu6_token):
    urdu6_token.remove("")

# %%
from nltk import ngrams
from collections import Counter

# %% [markdown]
# ### 1.2 - Creating Unigrams

# %% [markdown]
# Start by training a unigram model. For a unigram model, the n-gram probability is approximated by probability of the word in the unigram, as the model assumes independence:
#
# $$
# P(word) = \frac{n}{N}
# $$
#
# where n = count of the word in the corpus and N = total number of words in the corpus.

# %% [markdown]
# Generate a list of unigrams. Print the first 10 unigrams obtained.

# %%
def ngrams_extraction(token, num):
    n_grams = ngrams(token, num)
    return [ ' '.join(grams) for grams in n_grams]

# %%
unigram_story1 = ngrams_extraction(urdu1_token , 1)
unigram_story2 = ngrams_extraction(urdu2_token , 1)
unigram_story3 = ngrams_extraction(urdu3_token , 1)
unigram_story4 = ngrams_extraction(urdu4_token , 1)
unigram_story5 = ngrams_extraction(urdu5_token , 1)
unigram_story6 = ngrams_extraction(urdu6_token , 1)
total_unigram = unigram_story1 + unigram_story2 + unigram_story3 + unigram_story4 + unigram_story5 + unigram_story6

# %% [markdown]
# Find the probabilities for each unique unigram.

# %%
# code here
total_corpus_lenght = len(total_unigram)
unigram_elements = np.array(list(Counter(total_unigram).keys()))# unique words against there counts
unigram_count = np.array(list(Counter(total_unigram).values()))
unigram_prob = unigram_count  / total_corpus_lenght # counts

# %% [markdown]
# ### 1.3 - Creating Bigrams
# Now train a bigram model.

# %% [markdown]
# Generate a list of bigrams. Print the first 10 bigrams obtained.

# %%
# code here
bigram_story1 = ngrams_extraction(urdu1_token , 2)
bigram_story2 = ngrams_extraction(urdu2_token , 2)
bigram_story3 = ngrams_extraction(urdu3_token , 2)
bigram_story4 = ngrams_extraction(urdu4_token , 2)
bigram_story5 = ngrams_extraction(urdu5_token , 2)
bigram_story6 = ngrams_extraction(urdu6_token , 2)
total_bigram = bigram_story1 + bigram_story2 + bigram_story3 + bigram_story4 + bigram_story5 + bigram_story6

# %% [markdown]
# Find the probabilities for each unique bigram.

# %%
# code here
total_corpus_lenght = len(total_bigram)
bigram_elements = np.array(list(Counter(total_bigram).keys()))# unique words against there counts
bigram_counts = np.array(list(Counter(total_bigram).values())) # counts 

bigram_prob = []
for x in range(len(bigram_elements)):
    first_word = (bigram_elements[x].split())[0]
    for i in range(len(unigram_elements)):
        if unigram_elements[i] == first_word:
            prob_temp = bigram_counts[x] / unigram_count[i] 
            bigram_prob.append(prob_temp)

# %% [markdown]
# ### 1.4 - Creating Trigrams
# Lastly train a trigram model.

# %% [markdown]
# Generate a list of trigrams. Print the first 10 trigrams obtained.

# %%
# code here
trigram_story1 = ngrams_extraction(urdu1_token , 3)
trigram_story2 = ngrams_extraction(urdu2_token , 3)
trigram_story3 = ngrams_extraction(urdu3_token , 3)
trigram_story4 = ngrams_extraction(urdu4_token , 3)
trigram_story5 = ngrams_extraction(urdu5_token , 3)
trigram_story6 = ngrams_extraction(urdu6_token , 3)
total_trigram = trigram_story1 + trigram_story2 + trigram_story3 + trigram_story4 + trigram_story5 + trigram_story6

# %% [markdown]
# Find the probabilities for each unique trigram.

# %%
# code here
total_corpus_lenght = len(total_trigram)
trigram_elements = np.array(list(Counter(total_trigram).keys()))# unique words against there counts
trigram_counts = np.array(list(Counter(total_trigram).values())) # counts 

trigram_prob = []
for x in range(len(trigram_elements)):
    first_two_words = (trigram_elements[x].split())[0] + ' ' +  (trigram_elements[x].split())[1]     
    for i in range(len(bigram_elements)):
        if bigram_elements[i] == first_two_words:
            prob_temp = trigram_counts[x] / bigram_counts[i] 
            trigram_prob.append(prob_temp)

# %%
import random
def simplify(select_list , select_prob_count_list , sentence , bypass_flag):
    flag = False
    if bypass_flag == 'uni':
        bypass_flag = 'bi'
    else:
        bypass_flag = 'tri'
    df = pd.DataFrame()
    df['selection'] = select_list
    df['count'] = select_prob_count_list
    final_df = df.sort_values(by=['count'], ascending=True)
    final_list1 = list(final_df['selection'].values)
    final_list2 = final_list1[-5:] #Max top 5 bigrams are selected
    if (len(final_list2) != 0): #If the list is zero, bigram is not working anymore
        continue_sent = random.choice(final_list2) #Random selected amongst them 
        sentence.append(continue_sent.split()[-1]) #last Word
        temp = (" ".join(sentence))
        sentence = []
        sentence.append(temp)
    else:
        flag = True
    return sentence, flag , bypass_flag

# %% [markdown]
# ### 1.5 - Generating Text
# Generate a paragraph with ten sentences each containing 9-15 words (pick the length of the sentence randomly within this range) using you language model. Start with trigrams, use back-off technique (i.e. use n-1 gram) if a token is not available.
#
# For each word prediction, get top 5 most probabale words using the n-gram model and then pick the next word randomly from within these. This is being done to avoid excessive repetitive sequences in your generated text.

# %%
sentence = []
paragraph = []

# you give your inputs manually here, since it's urdu text input so you can't take it directly from user input.

#Starting your paragraph with following options (uncomment to apply accordingly)
# urdu_text = ...                   # Any urdu text of any lenght that you like (replace ... with urdu text)
# urdu_text = 'افسوس افسوس اس'      # Any Trigram
# urdu_text = 'افسوس افسوس'         # Any Bigram
# urdu_text = 'افسوس'               # Any Unigram
urdu_text = ''                      # No Word: Just start generating text (by default)
sentence.append(urdu_text)
flag = False
print('start \n')
for a in range(11):
    
    print('You are starting with ==>',sentence)
    if len(sentence[0].split()) < 2 :
        if len(sentence[0].split()) ==1:
            bypass_flag = 'bi'
            print(bypass_flag)
        else:
            bypass_flag = 'uni'
            print(bypass_flag)
    else:
        bypass_flag = 'tri'
        print(bypass_flag)

    for z in range(random.randrange(9, 16)): #Lenght of the sentence
        if bypass_flag == 'tri':
            print('trigram applied')
            #Taking it's last 2 words for continuation
            last_two_words = (sentence[0].split())[-2] + ' ' + (sentence[0].split())[-1] 
            print(last_two_words,'<== Context we are focusing on', '\n')

            select_list = []
            select_prob_count_list = []

            for x in range(len(trigram_elements)):
                word_match = (trigram_elements[x].split())[0] + ' ' + (trigram_elements[x].split())[1]
                if word_match == last_two_words:
                    select_list.append(trigram_elements[x])
                    select_prob_count_list.append(trigram_prob[x])
                    
            sentence , flag , bypass_flag  = simplify(select_list , select_prob_count_list , sentence ,bypass_flag)      
        
        if flag == True or bypass_flag == 'bi': #Bigram implemented once per cycle if need be
            print('bigram applied')
            last_word = (sentence[0].split())[-1] 
            print(last_word, '<== Context we are focusing on', '\n')

            select_list = []
            select_prob_count_list = []

            for x in range(len(bigram_elements)):
                word_match = (bigram_elements[x].split())[0] 
                if word_match == last_word:
                    select_list.append(bigram_elements[x])
                    select_prob_count_list.append(bigram_prob[x])
            sentence , flag , bypass_flag = simplify(select_list , select_prob_count_list , sentence , bypass_flag) 
        
        if flag == True  or bypass_flag == 'uni': #unigram implemented once per cycle if need be
            print('Unigram applied')
            select_prob_count_list = unigram_prob
            select_list = unigram_elements
            sentence , flag , bypass_flag = simplify(select_list , select_prob_count_list , sentence , bypass_flag) 
        print(sentence , '<=== updated urdu text \n')
    
    paragraph.append(sentence[0])
    sentence = ['']
paragraph = ("\n".join(paragraph))
# Out:
# start
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' کی'] <=== updated urdu text
#
# bigram applied
# کی <== Context we are focusing on
#
# [' کی وجہ'] <=== updated urdu text
#
# trigram applied
# کی وجہ <== Context we are focusing on
#
# [' کی وجہ سے'] <=== updated urdu text
#
# trigram applied
# وجہ سے <== Context we are focusing on
#
# [' کی وجہ سے میری'] <=== updated urdu text
#
# trigram applied
# سے میری <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو'] <=== updated urdu text
#
# trigram applied
# میری گفتگو <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں'] <=== updated urdu text
#
# trigram applied
# گفتگو میں <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں ایک'] <=== updated urdu text
#
# trigram applied
# میں ایک <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں ایک ایک'] <=== updated urdu text
#
# trigram applied
# ایک ایک <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں ایک ایک کو'] <=== updated urdu text
#
# trigram applied
# ایک کو <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں ایک ایک کو خط'] <=== updated urdu text
#
# trigram applied
# کو خط <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں ایک ایک کو خط لکھتے'] <=== updated urdu text
#
# trigram applied
# خط لکھتے <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں ایک ایک کو خط لکھتے رہتے'] <=== updated urdu text
#
# trigram applied
# لکھتے رہتے <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں ایک ایک کو خط لکھتے رہتے ہیں'] <=== updated urdu text
#
# trigram applied
# رہتے ہیں <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں ایک ایک کو خط لکھتے رہتے ہیں خالص'] <=== updated urdu text
#
# trigram applied
# ہیں خالص <== Context we are focusing on
#
# [' کی وجہ سے میری گفتگو میں ایک ایک کو خط لکھتے رہتے ہیں خالص گھی'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' کی'] <=== updated urdu text
#
# bigram applied
# کی <== Context we are focusing on
#
# [' کی وجہ'] <=== updated urdu text
#
# trigram applied
# کی وجہ <== Context we are focusing on
#
# [' کی وجہ سے'] <=== updated urdu text
#
# trigram applied
# وجہ سے <== Context we are focusing on
#
# [' کی وجہ سے اب'] <=== updated urdu text
#
# trigram applied
# سے اب <== Context we are focusing on
#
# [' کی وجہ سے اب یونیورسٹی'] <=== updated urdu text
#
# trigram applied
# اب یونیورسٹی <== Context we are focusing on
#
# [' کی وجہ سے اب یونیورسٹی نے'] <=== updated urdu text
#
# trigram applied
# یونیورسٹی نے <== Context we are focusing on
#
# [' کی وجہ سے اب یونیورسٹی نے کالجوں'] <=== updated urdu text
#
# trigram applied
# نے کالجوں <== Context we are focusing on
#
# [' کی وجہ سے اب یونیورسٹی نے کالجوں پر'] <=== updated urdu text
#
# trigram applied
# کالجوں پر <== Context we are focusing on
#
# [' کی وجہ سے اب یونیورسٹی نے کالجوں پر شرط'] <=== updated urdu text
#
# trigram applied
# پر شرط <== Context we are focusing on
#
# [' کی وجہ سے اب یونیورسٹی نے کالجوں پر شرط عائد'] <=== updated urdu text
#
# trigram applied
# شرط عائد <== Context we are focusing on
#
# [' کی وجہ سے اب یونیورسٹی نے کالجوں پر شرط عائد کر'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' میں'] <=== updated urdu text
#
# bigram applied
# میں <== Context we are focusing on
#
# [' میں سے'] <=== updated urdu text
#
# trigram applied
# میں سے <== Context we are focusing on
#
# [' میں سے ان'] <=== updated urdu text
#
# trigram applied
# سے ان <== Context we are focusing on
#
# [' میں سے ان کو'] <=== updated urdu text
#
# trigram applied
# ان کو <== Context we are focusing on
#
# [' میں سے ان کو باہر'] <=== updated urdu text
#
# trigram applied
# کو باہر <== Context we are focusing on
#
# [' میں سے ان کو باہر سے'] <=== updated urdu text
#
# trigram applied
# باہر سے <== Context we are focusing on
#
# [' میں سے ان کو باہر سے ہی'] <=== updated urdu text
#
# trigram applied
# سے ہی <== Context we are focusing on
#
# [' میں سے ان کو باہر سے ہی کھاآئے'] <=== updated urdu text
#
# trigram applied
# ہی کھاآئے <== Context we are focusing on
#
# [' میں سے ان کو باہر سے ہی کھاآئے تھے'] <=== updated urdu text
#
# trigram applied
# کھاآئے تھے <== Context we are focusing on
#
# [' میں سے ان کو باہر سے ہی کھاآئے تھے بستر'] <=== updated urdu text
#
# trigram applied
# تھے بستر <== Context we are focusing on
#
# [' میں سے ان کو باہر سے ہی کھاآئے تھے بستر میں'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' ہے'] <=== updated urdu text
#
# bigram applied
# ہے <== Context we are focusing on
#
# [' ہے اس'] <=== updated urdu text
#
# trigram applied
# ہے اس <== Context we are focusing on
#
# [' ہے اس کھڑکی'] <=== updated urdu text
#
# trigram applied
# اس کھڑکی <== Context we are focusing on
#
# [' ہے اس کھڑکی پر'] <=== updated urdu text
#
# trigram applied
# کھڑکی پر <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی'] <=== updated urdu text
#
# trigram applied
# پر کسی <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی مشہور'] <=== updated urdu text
#
# trigram applied
# کسی مشہور <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی مشہور لیڈر'] <=== updated urdu text
#
# trigram applied
# مشہور لیڈر <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی مشہور لیڈر کے'] <=== updated urdu text
#
# trigram applied
# لیڈر کے <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی مشہور لیڈر کے خانگی'] <=== updated urdu text
#
# trigram applied
# کے خانگی <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی مشہور لیڈر کے خانگی حالت'] <=== updated urdu text
#
# trigram applied
# خانگی حالت <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی مشہور لیڈر کے خانگی حالت بال'] <=== updated urdu text
#
# trigram applied
# حالت بال <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی مشہور لیڈر کے خانگی حالت بال وضاحت'] <=== updated urdu text
#
# trigram applied
# بال وضاحت <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی مشہور لیڈر کے خانگی حالت بال وضاحت بیان'] <=== updated urdu text
#
# trigram applied
# وضاحت بیان <== Context we are focusing on
#
# [' ہے اس کھڑکی پر کسی مشہور لیڈر کے خانگی حالت بال وضاحت بیان کر'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' اور'] <=== updated urdu text
#
# bigram applied
# اور <== Context we are focusing on
#
# [' اور آپ'] <=== updated urdu text
#
# trigram applied
# اور آپ <== Context we are focusing on
#
# [' اور آپ چیختے'] <=== updated urdu text
#
# trigram applied
# آپ چیختے <== Context we are focusing on
#
# [' اور آپ چیختے اور'] <=== updated urdu text
#
# trigram applied
# چیختے اور <== Context we are focusing on
#
# [' اور آپ چیختے اور سسکتے'] <=== updated urdu text
#
# trigram applied
# اور سسکتے <== Context we are focusing on
#
# [' اور آپ چیختے اور سسکتے رہ'] <=== updated urdu text
#
# trigram applied
# سسکتے رہ <== Context we are focusing on
#
# [' اور آپ چیختے اور سسکتے رہ جائیں'] <=== updated urdu text
#
# trigram applied
# رہ جائیں <== Context we are focusing on
#
# [' اور آپ چیختے اور سسکتے رہ جائیں گے'] <=== updated urdu text
#
# trigram applied
# جائیں گے <== Context we are focusing on
#
# [' اور آپ چیختے اور سسکتے رہ جائیں گے چنانچے'] <=== updated urdu text
#
# trigram applied
# گے چنانچے <== Context we are focusing on
#
# [' اور آپ چیختے اور سسکتے رہ جائیں گے چنانچے ساتویں'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' ہے'] <=== updated urdu text
#
# bigram applied
# ہے <== Context we are focusing on
#
# [' ہے اور'] <=== updated urdu text
#
# trigram applied
# ہے اور <== Context we are focusing on
#
# [' ہے اور آپ'] <=== updated urdu text
#
# trigram applied
# اور آپ <== Context we are focusing on
#
# [' ہے اور آپ پژمردہ'] <=== updated urdu text
#
# trigram applied
# آپ پژمردہ <== Context we are focusing on
#
# [' ہے اور آپ پژمردہ ہو'] <=== updated urdu text
#
# trigram applied
# پژمردہ ہو <== Context we are focusing on
#
# [' ہے اور آپ پژمردہ ہو جاتے'] <=== updated urdu text
#
# trigram applied
# ہو جاتے <== Context we are focusing on
#
# [' ہے اور آپ پژمردہ ہو جاتے ہیں'] <=== updated urdu text
#
# trigram applied
# جاتے ہیں <== Context we are focusing on
#
# [' ہے اور آپ پژمردہ ہو جاتے ہیں صحت'] <=== updated urdu text
#
# trigram applied
# ہیں صحت <== Context we are focusing on
#
# [' ہے اور آپ پژمردہ ہو جاتے ہیں صحت یاب'] <=== updated urdu text
#
# trigram applied
# صحت یاب <== Context we are focusing on
#
# [' ہے اور آپ پژمردہ ہو جاتے ہیں صحت یاب ہو'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' میں'] <=== updated urdu text
#
# bigram applied
# میں <== Context we are focusing on
#
# [' میں اس'] <=== updated urdu text
#
# trigram applied
# میں اس <== Context we are focusing on
#
# [' میں اس کے'] <=== updated urdu text
#
# trigram applied
# اس کے <== Context we are focusing on
#
# [' میں اس کے علاوہ'] <=== updated urdu text
#
# trigram applied
# کے علاوہ <== Context we are focusing on
#
# [' میں اس کے علاوہ چال'] <=== updated urdu text
#
# trigram applied
# علاوہ چال <== Context we are focusing on
#
# [' میں اس کے علاوہ چال چلن'] <=== updated urdu text
#
# trigram applied
# چال چلن <== Context we are focusing on
#
# [' میں اس کے علاوہ چال چلن بھی'] <=== updated urdu text
#
# trigram applied
# چلن بھی <== Context we are focusing on
#
# [' میں اس کے علاوہ چال چلن بھی اچھا'] <=== updated urdu text
#
# trigram applied
# بھی اچھا <== Context we are focusing on
#
# [' میں اس کے علاوہ چال چلن بھی اچھا ہونا'] <=== updated urdu text
#
# trigram applied
# اچھا ہونا <== Context we are focusing on
#
# [' میں اس کے علاوہ چال چلن بھی اچھا ہونا چاہئے'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' ہے'] <=== updated urdu text
#
# bigram applied
# ہے <== Context we are focusing on
#
# [' ہے اور'] <=== updated urdu text
#
# trigram applied
# ہے اور <== Context we are focusing on
#
# [' ہے اور آپ'] <=== updated urdu text
#
# trigram applied
# اور آپ <== Context we are focusing on
#
# [' ہے اور آپ چیختے'] <=== updated urdu text
#
# trigram applied
# آپ چیختے <== Context we are focusing on
#
# [' ہے اور آپ چیختے اور'] <=== updated urdu text
#
# trigram applied
# چیختے اور <== Context we are focusing on
#
# [' ہے اور آپ چیختے اور سسکتے'] <=== updated urdu text
#
# trigram applied
# اور سسکتے <== Context we are focusing on
#
# [' ہے اور آپ چیختے اور سسکتے رہ'] <=== updated urdu text
#
# trigram applied
# سسکتے رہ <== Context we are focusing on
#
# [' ہے اور آپ چیختے اور سسکتے رہ جائیں'] <=== updated urdu text
#
# trigram applied
# رہ جائیں <== Context we are focusing on
#
# [' ہے اور آپ چیختے اور سسکتے رہ جائیں گے'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' کے'] <=== updated urdu text
#
# bigram applied
# کے <== Context we are focusing on
#
# [' کے متعلق'] <=== updated urdu text
#
# trigram applied
# کے متعلق <== Context we are focusing on
#
# [' کے متعلق میں'] <=== updated urdu text
#
# trigram applied
# متعلق میں <== Context we are focusing on
#
# [' کے متعلق میں تم'] <=== updated urdu text
#
# trigram applied
# میں تم <== Context we are focusing on
#
# [' کے متعلق میں تم سے'] <=== updated urdu text
#
# trigram applied
# تم سے <== Context we are focusing on
#
# [' کے متعلق میں تم سے کتنی'] <=== updated urdu text
#
# trigram applied
# سے کتنی <== Context we are focusing on
#
# [' کے متعلق میں تم سے کتنی بحث'] <=== updated urdu text
#
# trigram applied
# کتنی بحث <== Context we are focusing on
#
# [' کے متعلق میں تم سے کتنی بحث کرتا'] <=== updated urdu text
#
# trigram applied
# بحث کرتا <== Context we are focusing on
#
# [' کے متعلق میں تم سے کتنی بحث کرتا رہا'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' کے'] <=== updated urdu text
#
# bigram applied
# کے <== Context we are focusing on
#
# [' کے بعد'] <=== updated urdu text
#
# trigram applied
# کے بعد <== Context we are focusing on
#
# [' کے بعد پھر'] <=== updated urdu text
#
# trigram applied
# بعد پھر <== Context we are focusing on
#
# [' کے بعد پھر سال'] <=== updated urdu text
#
# trigram applied
# پھر سال <== Context we are focusing on
#
# [' کے بعد پھر سال بھر'] <=== updated urdu text
#
# trigram applied
# سال بھر <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں'] <=== updated urdu text
#
# trigram applied
# بھر میں <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں ماموں'] <=== updated urdu text
#
# trigram applied
# میں ماموں <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں ماموں کے'] <=== updated urdu text
#
# trigram applied
# ماموں کے <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں ماموں کے گھر'] <=== updated urdu text
#
# trigram applied
# کے گھر <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں ماموں کے گھر اس'] <=== updated urdu text
#
# trigram applied
# گھر اس <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں ماموں کے گھر اس سے'] <=== updated urdu text
#
# trigram applied
# اس سے <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں ماموں کے گھر اس سے ان'] <=== updated urdu text
#
# trigram applied
# سے ان <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں ماموں کے گھر اس سے ان ہیںکبھی'] <=== updated urdu text
#
# trigram applied
# ان ہیںکبھی <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں ماموں کے گھر اس سے ان ہیںکبھی کپڑے'] <=== updated urdu text
#
# trigram applied
# ہیںکبھی کپڑے <== Context we are focusing on
#
# [' کے بعد پھر سال بھر میں ماموں کے گھر اس سے ان ہیںکبھی کپڑے اتارنے'] <=== updated urdu text
#
# You are starting with ==> ['']
# uni
# Unigram applied
# [' کی'] <=== updated urdu text
#
# bigram applied
# کی <== Context we are focusing on
#
# [' کی ایک'] <=== updated urdu text
#
# trigram applied
# کی ایک <== Context we are focusing on
#
# [' کی ایک کھڑکی'] <=== updated urdu text
#
# trigram applied
# ایک کھڑکی <== Context we are focusing on
#
# [' کی ایک کھڑکی میں'] <=== updated urdu text
#
# trigram applied
# کھڑکی میں <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے'] <=== updated urdu text
#
# trigram applied
# میں سے <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان'] <=== updated urdu text
#
# trigram applied
# سے ان <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان پر'] <=== updated urdu text
#
# trigram applied
# ان پر <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان پر اچھی'] <=== updated urdu text
#
# trigram applied
# پر اچھی <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان پر اچھی طرح'] <=== updated urdu text
#
# trigram applied
# اچھی طرح <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان پر اچھی طرح معلوم'] <=== updated urdu text
#
# trigram applied
# طرح معلوم <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان پر اچھی طرح معلوم ہے'] <=== updated urdu text
#
# trigram applied
# معلوم ہے <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان پر اچھی طرح معلوم ہے کہ'] <=== updated urdu text
#
# trigram applied
# ہے کہ <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان پر اچھی طرح معلوم ہے کہ ہماری'] <=== updated urdu text
#
# trigram applied
# کہ ہماری <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان پر اچھی طرح معلوم ہے کہ ہماری باقاعدگی'] <=== updated urdu text
#
# trigram applied
# ہماری باقاعدگی <== Context we are focusing on
#
# [' کی ایک کھڑکی میں سے ان پر اچھی طرح معلوم ہے کہ ہماری باقاعدگی میں'] <=== updated urdu text

# %%
print('Final Text:')
print(paragraph)
# Out:
# Final Text:
#  کی وجہ سے میری گفتگو میں ایک ایک کو خط لکھتے رہتے ہیں خالص گھی
#  کی وجہ سے اب یونیورسٹی نے کالجوں پر شرط عائد کر
#  میں سے ان کو باہر سے ہی کھاآئے تھے بستر میں
#  ہے اس کھڑکی پر کسی مشہور لیڈر کے خانگی حالت بال وضاحت بیان کر
#  اور آپ چیختے اور سسکتے رہ جائیں گے چنانچے ساتویں
#  ہے اور آپ پژمردہ ہو جاتے ہیں صحت یاب ہو
#  میں اس کے علاوہ چال چلن بھی اچھا ہونا چاہئے
#  ہے اور آپ چیختے اور سسکتے رہ جائیں گے
#  کے متعلق میں تم سے کتنی بحث کرتا رہا
#  کے بعد پھر سال بھر میں ماموں کے گھر اس سے ان ہیںکبھی کپڑے اتارنے
#  کی ایک کھڑکی میں سے ان پر اچھی طرح معلوم ہے کہ ہماری باقاعدگی میں

# %% [markdown]
# ### 1.6 - Discussion and Evaluation

# %% [markdown]
# - Analyze the text generated, and mention 3 distinct observations. Also compare it with the input text and how different it is and why might that be.
# - Is going upto n=3 enough? What do you think would be a good value of n and why?
#
# Answer here:

# %%
# three distinct observations that i observed was:
# 1) Each sentence has a context of it's own, there is no link between the sentences in terms of continuos ideology 
# 2) Some sentences in the text doesn't have a complete idea of it's own, like it starts saying something
#    and then switches to a different series of words that portrays different meaning with no link 
#    to the previous words; in a single sentence.
# 3) the lenght of sentences are not coherent with each other in the paragraph.
# Comparing this generated text to the input text, it is very different in terms of the portrayal of ideas and 
# context but pretty similar in terms of writing style of the author. The reason for that is because this model 
# analysis the previous text of the author and generates new text strictly based what it is trained on, each new
# word is selected based upon its probabilty of n gram it is present in, which lead to sentences not making any sense.
# hence when new ideas are needed to be produced through text, the model starts off with words that breaks the
# idea of the previous sentence into forming a new sentence in response to the new idea, which in reality
# is incoherent with the entire context as a whole



# going up to n=3 is not enough. An idealy good value would be (n = lenght of the entire text). By doing this,
# coherence of phrases will not only be limited to three words but the randomness of the sentence structure in 
# terms of a non-continuos idea will vanish and the text produced will not only be similar to the author's style
# but also similar to the ideolgy of author that he wants to portrey in his paragraph.
